# %%
a=int(input("Enter number"))
if a%2==0:
    
    print("even")
else : 
    print("odd")
# Out:
# Enter number 3
# odd

# %%
a=int(input("Enter number"))
if a%3==0 and a%5==0:
    
    print("Yes")
else : 
    print("NO")
# Out:
# Enter number 105
# Yes

# %%
a=int(input("Enter number"))
if a%9==0 or a%7==0:
    
    print("Heloo bye")
else : 
    print("Chal be")
# Out:
# Enter number 21
# Heloo bye

# %%
print("Grade System")
a=int(input("Enter number"))
if a>=90 and a<=100:
    print("A")
elif (a>=80 and a<=89): 
    print("B")
elif (a>=70 and a<=79): 
    print("C")
elif (a>=60 and a<=69): 
    print("D")
else :
    print("Fail")
# Out:
# Grade System
# Enter number 90
# A

# %%
a=int(input("Enter number"))
a=int(input("Enter number"))
# Out:
# Enter number 34
# Enter number 34

# %%
a=int(input("Enter number"))
b=int(input("Enter number"))
c=int(input("Enter number"))
if a>b :
    if a>c:
        print(a,"Biggest number")
    else :
        print(c,"Biggest number")
else:
    if b>c:
        print(b,"Biggest Number")
    else: 
        print(c,"Biggest Number")
# Out:
# Enter number 1
# Enter number 3
# Enter number 2
# 3 Biggest Number

# %%
year=int(input("Enter year"))
if year%400:
    print("leap year")
elif year%4==0 and year%100!=0:
    print("leap year")
else:
    print("not")
# Out:
# Enter year 2019
# not

# %%
for i in range(1,51):
    if i%3==0 or i%5==0:
        print(i)
# Out:
# 3
# 5
# 6
# 9
# 10
# 12
# 15
# 18
# 20
# 21
# 24
# 25
# 27
# 30
# 33
# 35
# 36
# 39
# 40
# 42
# 45
# 48
# 50

# %%
a=int(input("Enter numvber "))
for i in range(1,11):
    print(f"{a} * {i} = {a*i} ")
# Out:
# Enter numvber  4
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40

# %%
a=int(input("Enter numvber "))
for i in range(10,0,-1):
    print(f"{a} * {i} = {a*i} ")
# Out:
# Enter numvber  7
# 7 * 10 = 70
# 7 * 9 = 63
# 7 * 8 = 56
# 7 * 7 = 49
# 7 * 6 = 42
# 7 * 5 = 35
# 7 * 4 = 28
# 7 * 3 = 21
# 7 * 2 = 14
# 7 * 1 = 7

# %%
s=0
c=0
for i in range(1,5):
    a=int(input("Enter marks"))
    s+=a
    c+=1
print(f"Total marks is {s} and their avg is {s/c}")
# Out:
# Enter marks 10
# Enter marks 20
# Enter marks 30
# Enter marks 40
# Total marks is 100 and their avg is 25.0

# %%
s=int(input("Enter number"))
for i in range(1,s)
     print(1*)
