# %%
print("Het is a \n brilliant\n boy")
# Out:
# Het is a
#  brilliant
#  boy

# %%
print("Het is a \n
brilliant\nboy")
# Out:
#   Cell In[2], line 1
#     print("Het is a \n
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
pok jhugyK`!m Q23WRTYL
# Out:
# Het is a
#  brilliant
#  boy

# %%
print("Het is a \n brilliant\n
boy")
# Out:
#   Cell In[4], line 1
#     print("Het is a \n brilliant\n
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
name="het"
age=18
Education="Lj'25"
print(f" My name is{name} age is {18} studies in{Education}")
# Out:
#  My name ishet age is 18 studies inLj'25

# %%
a=40
b=3
print(f"sum of {a} and {b} is {a+b}")
print(f"sub of {a} and {b} is {a-b}")
print(f"sum of {a} and {b} is {a*b}")
print(f"sum of {a} and {b} is {a%b}")
print(f"sum of {a} and {b} is {a/b}")
print(f"sum of {a} and {b} is {a//b}")
# Out:
# sum of 40 and 3 is 43
# sub of 40 and 3 is 37
# sum of 40 and 3 is 120
# sum of 40 and 3 is 1
# sum of 40 and 3 is 13.333333333333334
# sum of 40 and 3 is 13

# %%
//?
# Out:
#   Cell In[1], line 1
#     //?
#     ^
# SyntaxError: invalid syntax

# %%
chr(75)
   chr(k)
# Out:
#   Cell In[4], line 2
#     chr(k)
#     ^
# IndentationError: unexpected indent

# %%
a=float(input("Enter kar radius"))
x=22/7
print(x*(a**2),"units")
# Out:
# Enter kar radius 10
# 314.2857142857143 units

# %%
days=int(input("enter no of days"))
year=days//360
r=days%30
m=r//30
d=r%30
print(year,m,d)
# Out:
# enter no of days 392
# 1 0 2

# %%
sec=int(input("enter no of seconds"))
h=sec//3600
r=sec%3600
m=r//60
fsec=r%60
print(h,m,fsec)
# Out:
# enter no of seconds 36001
# 10 0 1

# %%
sec=int(input("enter no of seconds"))
ysec=3600*24*360
msec=3600*24*30
dsec=3600*24
 year=sec//ysec
r=sec%ysec
mon=r//msec
day=r%msec
hour=
